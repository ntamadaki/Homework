# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
tanea_df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Notebooks εργασίας/TA NEA/tanea_articles_final csv (1).txt')
tanea_df
# Out:
#          site                                                url  \
# 0    tanea.gr  https://www.tanea.gr/2026/06/09/politics/tsouk...
# 1    tanea.gr  https://www.tanea.gr/2026/06/07/politics/ypokl...
# 2    tanea.gr  https://www.tanea.gr/2026/06/04/politics/maksi...
# 3    tanea.gr  https://www.tanea.gr/2026/06/04/greece/ypoklop...
# 4    tanea.gr  https://www.tanea.gr/2026/06/02/politics/ypokl...
# ..        ...                                                ...
# 139  tanea.gr  https://www.tanea.gr/2025/02/11/greece/ypoklop...
# 140  tanea.gr  https://www.tanea.gr/2025/01/29/greece/ypoklop...
# 141  tanea.gr  https://www.tanea.gr/2024/11/27/media/sta-nea-...
# 142  tanea.gr  https://www.tanea.gr/2024/11/01/politics/omili...
# 143  tanea.gr  https://www.tanea.gr/2024/09/29/politics/rammo...
#
#                                               headline  category  \
# 0    Απάντηση Τσουκαλά σε Φλωρίδη: Να ανασυρθεί από...  Πολιτική
# ...

# %%
tanea_df.isnull().sum()
# Out:
# site          0
# url           0
# headline      0
# category      0
# author       93
# date          0
# full_text     0
# dtype: int64

# %%
tanea_df[tanea_df['date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [site, url, headline, category, author, date, full_text]
# Index: []

# %%
tanea_df.dtypes
# Out:
# site         object
# url          object
# headline     object
# category     object
# author       object
# date         object
# full_text    object
# dtype: object

# %%
tanea_df ['date']= pd.to_datetime(tanea_df['date'], format='%d/%m/%Y %H:%M', errors='coerce')
tanea_df.to_csv('tanea_df_2025-26.csv', index=False)
display(tanea_df)
# Out:
#          site                                                url  \
# 0    tanea.gr  https://www.tanea.gr/2026/06/09/politics/tsouk...
# 1    tanea.gr  https://www.tanea.gr/2026/06/07/politics/ypokl...
# 2    tanea.gr  https://www.tanea.gr/2026/06/04/politics/maksi...
# 3    tanea.gr  https://www.tanea.gr/2026/06/04/greece/ypoklop...
# 4    tanea.gr  https://www.tanea.gr/2026/06/02/politics/ypokl...
# ..        ...                                                ...
# 139  tanea.gr  https://www.tanea.gr/2025/02/11/greece/ypoklop...
# 140  tanea.gr  https://www.tanea.gr/2025/01/29/greece/ypoklop...
# 141  tanea.gr  https://www.tanea.gr/2024/11/27/media/sta-nea-...
# 142  tanea.gr  https://www.tanea.gr/2024/11/01/politics/omili...
# 143  tanea.gr  https://www.tanea.gr/2024/09/29/politics/rammo...
#
#                                               headline  category  \
# 0    Απάντηση Τσουκαλά σε Φλωρίδη: Να ανασυρθεί από...  Πολιτική
# ...

# %%
tanea_df_new = tanea_df[tanea_df['date'].dt.year != 2024]
tanea_df_new.to_csv('tanea_df_2025-26.csv', index=False)
display(tanea_df_new)
# Out:
#          site                                                url  \
# 0    tanea.gr  https://www.tanea.gr/2026/06/09/politics/tsouk...
# 1    tanea.gr  https://www.tanea.gr/2026/06/07/politics/ypokl...
# 2    tanea.gr  https://www.tanea.gr/2026/06/04/politics/maksi...
# 3    tanea.gr  https://www.tanea.gr/2026/06/04/greece/ypoklop...
# 4    tanea.gr  https://www.tanea.gr/2026/06/02/politics/ypokl...
# ..        ...                                                ...
# 136  tanea.gr  https://www.tanea.gr/2025/10/22/politics/andro...
# 137  tanea.gr  https://www.tanea.gr/2025/08/24/science-techno...
# 138  tanea.gr  https://www.tanea.gr/2025/07/22/politics/epane...
# 139  tanea.gr  https://www.tanea.gr/2025/02/11/greece/ypoklop...
# 140  tanea.gr  https://www.tanea.gr/2025/01/29/greece/ypoklop...
#
#                                               headline               category  \
# 0    Απάντηση Τσουκαλά σε Φλωρίδη: Να ανασυρθεί από...               Πολιτική
# ...

# %%
tanea_df_new.dtypes
# Out:
# site                 object
# url                  object
# headline             object
# category             object
# author               object
# date         datetime64[ns]
# full_text            object
# dtype: object

# %%
short_tanea_df = tanea_df_new[['date','full_text']]
short_tanea_df
# Out:
#                    date                                          full_text
# 0   2026-06-09 16:39:00  Έντονη κριτική στην κυβέρνησημε αφορμή τις δηλ...
# 1   2026-06-07 16:38:00  Έντονους κραδασμούς στο κυβερνητικό στρατόπεδο...
# 2   2026-06-04 13:20:00  Για τηστάση της κυβέρνησης μπροστά στο αίτημα ...
# 3   2026-06-04 12:24:00  Νέα δεδομένα στηνπολύκροτη υπόθεση των τηλεφων...
# 4   2026-06-02 17:03:00  Αίτημαγια ακρόαση τωνΤαλ ΝτίλιανκαιΓρηγόρη Δημ...
# ..                  ...                                                ...
# 136 2025-10-22 17:47:00  Μετά την ολοκλήρωση της κατάθεσης του στη δίκη...
# 137 2025-08-24 18:27:00  Μια νέα τεχνολογία υποκλοπής φέρνει στο προσκή...
# 138 2025-07-22 12:04:00  Στο δικαστικό προσκήνιο επανέρχεται η υπόθεση ...
# 139 2025-02-11 14:28:00  Με το σκεπτικό ότι η υπόθεση των τηλεφωνικών υ...
# 140 2025-01-29 11:12:00  Στο αρχείο έθεσε ο αντεισαγγελέας του Αρείου Π...
#
# [141 rows x 2 columns]

# %%
short_tanea_df['year'] = pd.DatetimeIndex(short_tanea_df['date']).year.astype('Int64')
short_tanea_df['month'] = pd.DatetimeIndex(short_tanea_df['date']).month.astype('Int64')
short_tanea_df['day'] = pd.DatetimeIndex(short_tanea_df['date']).day.astype('Int64')
short_tanea_df['hour'] = pd.DatetimeIndex(short_tanea_df['date']).hour.astype('Int64')
# Out:
# /tmp/ipykernel_8410/3235075328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_tanea_df['year'] = pd.DatetimeIndex(short_tanea_df['date']).year.astype('Int64')
# /tmp/ipykernel_8410/3235075328.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   short_tanea_df['month'] = pd.DatetimeIndex(short_tanea_df['date']).month.astype('Int64')
# /tmp/ipykernel_8410/3235075328.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
short_tanea_df
short_tanea_df.to_csv('short_tanea_df.csv', index=False)

# %%
short_tanea_df
# Out:
#                    date                                          full_text  \
# 0   2026-06-09 16:39:00  Έντονη κριτική στην κυβέρνησημε αφορμή τις δηλ...
# 1   2026-06-07 16:38:00  Έντονους κραδασμούς στο κυβερνητικό στρατόπεδο...
# 2   2026-06-04 13:20:00  Για τηστάση της κυβέρνησης μπροστά στο αίτημα ...
# 3   2026-06-04 12:24:00  Νέα δεδομένα στηνπολύκροτη υπόθεση των τηλεφων...
# 4   2026-06-02 17:03:00  Αίτημαγια ακρόαση τωνΤαλ ΝτίλιανκαιΓρηγόρη Δημ...
# ..                  ...                                                ...
# 136 2025-10-22 17:47:00  Μετά την ολοκλήρωση της κατάθεσης του στη δίκη...
# 137 2025-08-24 18:27:00  Μια νέα τεχνολογία υποκλοπής φέρνει στο προσκή...
# 138 2025-07-22 12:04:00  Στο δικαστικό προσκήνιο επανέρχεται η υπόθεση ...
# 139 2025-02-11 14:28:00  Με το σκεπτικό ότι η υπόθεση των τηλεφωνικών υ...
# 140 2025-01-29 11:12:00  Στο αρχείο έθεσε ο αντεισαγγελέας του Αρείου Π...
#
#      year  month  day  hour
# 0    2026      6    9    16
# ...

# %%
short_tanea_df['month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>
